# %% [markdown]
# # Algorithmic Motion Planning (236610)
# John Noonan and Eli Shafer<br>
# Homework 3<br>
# January 2020

# %% [markdown]
# For the experimentation below, the weights for the wA* algorithm were chosen to be $w \in \{2, 3, 5, 10, 20\}$ and the weights for MHA* were chosen to be $w_2 = \text{min}(2.0, \sqrt{w})$ and $w_1 = \frac{w}{w_2}$.

# %% [markdown]
# ## Map 1

# %% [markdown]
# #### wA* Results

# %% [markdown]
# <div style="width: 100%; overflow: hidden;">
#     <div class="table" style="width: 400px; float: left;">
#         <table>
#             <tr>
#                 <th> $w$ </th>
#                 <th> # Expanded<br> Nodes </th>
#                 <th> Path<br>Cost </th>
#                 <th> Within Bound<br>(Optimal Cost = 486) </th>
#             </tr>
#             <tr>
#                 <td> 2 </td>
#                 <td> 23055 </td>
#                 <td> 518.10 </td>
#                 <td> $\checkmark$ $518.10 \leq 2\cdot \mathbf{486}$ </td>
#             </tr>
#             <tr>
#                 <td> 3 </td>
#                 <td> 11725 </td>
#                 <td> 745.88 </td>
#                 <td> $\checkmark$ $745.88 \leq 3\cdot \mathbf{486}$ </td>
#             </tr>
#             <tr>
#                 <td> 5 </td>
#                 <td> 7217 </td>
#                 <td> 754.08 </td>
#                 <td> $\checkmark$ $754.08 \leq 5\cdot \mathbf{486}$ </td>
#             </tr>
#             <tr>
#                 <td> 10 </td>
#                 <td> 5222 </td>
#                 <td> 765.21 </td>
#                 <td> $\checkmark$ $765.21 \leq 10\cdot \mathbf{486}$ </td>
#             </tr>
#             <tr>
#                 <td> 20 </td>
#                 <td> 4881 </td>
#                 <td> 766.97 </td>
#                 <td> $\checkmark$ $766.97 \leq 20\cdot \mathbf{486}$ </td>
#             </tr>
#         </table>
#     </div>
#     <div class="vis" style="margin-left: 270px;">
#         <img src="./imgs/astar_map1_w20.png" style="max-width: 70%" />
#     </div>
# </div>
#
# Note: The visualization is for $w = 20$.

# %% [markdown]
# #### MHA* Results

# %% [markdown]
# <div style="width: 100%; overflow: hidden;">
#     <div class="table" style="width: 420px; float: left;">
#         <table>
#             <tr>
#                 <th> $w_1$ </th>
#                 <th> $w_2$ </th>
#                 <th> # Expanded<br>Nodes </th>
#                 <th> Path<br>Cost </th>
#                 <th> Within Bound (Optimal Cost = 486) </th>
#             </tr>
#             <tr>
#                 <td> 1.41 </td>
#                 <td> 1.41 </td>
#                 <td> 2301 </td>
#                 <td> 693.25 </td>
#                 <td> $\checkmark$ $693.25 \leq 1.41\cdot 1.41 \cdot \mathbf{486}$ </td>
#             </tr>
#             <tr>
#                 <td> 1.73 </td>
#                 <td> 1.73 </td>
#                 <td> 2263 </td>
#                 <td> 695.60 </td>
#                 <td> $\checkmark$ $695.60 \leq 1.73\cdot 1.73 \cdot \mathbf{486}$ </td>
#             </tr>
#             <tr>
#                 <td> 2 </td>
#                 <td> 1.2 </td>
#                 <td> 23281 </td>
#                 <td> 520.83 </td>
#                 <td> $\checkmark$ $ \leq 2\cdot 1.2 \cdot \mathbf{486}$ </td>
#             </tr>
#             <tr>
#                 <td> 2 </td>
#                 <td> 1.41 </td>
#                 <td> 2967 </td>
#                 <td> 510.26 </td>
#                 <td> $\checkmark$ $510.26 \leq 2\cdot 1.41 \cdot \mathbf{486}$ </td>
#             </tr>
#
#             <tr>
#                 <td> 2.5 </td>
#                 <td> 2 </td>
#                 <td> 2229 </td>
#                 <td> 700.28 </td>
#                 <td> $\checkmark$ $700.28 \leq 2.5\cdot 2 \cdot \mathbf{486}$ </td>
#             </tr>
#             <tr>
#                 <td> 5 </td>
#                 <td> 2 </td>
#                 <td> 2163 </td>
#                 <td> 700.28 </td>
#                 <td> $\checkmark$ $700.28 \leq 5\cdot 2 \cdot \mathbf{486}$ </td>
#             </tr>
#             <tr>
#                 <td> 10 </td>
#                 <td> 2 </td>
#                 <td> 2138 </td>
#                 <td> 700.28 </td>
#                 <td> $\checkmark$ $700.28 \leq 10\cdot 2 \cdot \mathbf{486}$ </td>
#             </tr>
#         </table>
#     </div>
#     <div class="vis" style="margin-left: 270px;">
#         <img src="./imgs/mhastar_map1_w2w14.png" style="max-width: 70%" />
#     </div>
# </div>
#
# Note: The visualization is for $w_1 = 2$ and $w_2 = 1.41$.

# %% [markdown]
# ## Map 2

# %% [markdown]
# #### wA* Results

# %% [markdown]
# <div style="width: 100%; overflow: hidden;">
#     <div class="table" style="width: 400px; float: left;">
#         <table>
#             <tr>
#                 <th> $w$ </th>
#                 <th> # Expanded<br>Nodes </th>
#                 <th> Path Cost </th>
#                 <th> Within Bound<br>(Optimal Cost = 569) </th>
#             </tr>
#             <tr>
#                 <td> 2 </td>
#                 <td> 2814 </td>
#                 <td> 609.36 </td>
#                 <td> $\checkmark$ $609.36 \leq 2\cdot \mathbf{569}$ </td>
#             </tr>
#             <tr>
#                 <td> 3 </td>
#                 <td> 1740 </td>
#                 <td> 609.36 </td>
#                 <td> $\checkmark$ $609.36 \leq 3\cdot \mathbf{569}$ </td>
#             </tr>
#             <tr>
#                 <td> 5 </td>
#                 <td> 1664 </td>
#                 <td> 609.36 </td>
#                 <td> $\checkmark$ $609.36 \leq 5\cdot \mathbf{569}$ </td>
#             </tr>
#             <tr>
#                 <td> 10 </td>
#                 <td> 1664 </td>
#                 <td> 609.36 </td>
#                 <td> $\checkmark$ $609.36 \leq 10\cdot \mathbf{569}$ </td>
#             </tr>
#             <tr>
#                 <td> 20 </td>
#                 <td> 1664 </td>
#                 <td> 610.19 </td>
#                 <td> $\checkmark$ $610.19\leq 20\cdot \mathbf{569}$ </td>
#             </tr>
#         </table>
#     </div>
#     <div class="vis" style="margin-left: 270px;">
#         <img src="./imgs/astar_map2_w20.png" style="max-width: 70%" />
#     </div>
# </div>
#
# Note: The visualization is for $w = 20$.

# %% [markdown]
# #### MHA* Results

# %% [markdown]
# <div style="width: 100%; overflow: hidden;">
#     <div class="table" style="width: 420px; float: left;">
#         <table>
#             <tr>
#                 <th> $w_1$ </th>
#                 <th> $w_2$ </th>
#                 <th> # Expanded<br>Nodes </th>
#                 <th> Path<br>Cost</th>
#                 <th> Within Bound (Optimal Cost = 569) </th>
#             </tr>
#             <tr>
#                 <td> 1.41 </td>
#                 <td> 1.41 </td>
#                 <td> 2050 </td>
#                 <td> 680.83 </td>
#                 <td> $\checkmark$ $680.83 \leq 1.41\cdot 1.41 \cdot \mathbf{569}$ </td>
#             </tr>
#             <tr>
#                 <td> 1.73 </td>
#                 <td> 1.73 </td>
#                 <td> 2050 </td>
#                 <td> 680.83 </td>
#                 <td> $\checkmark$ $680.83 \leq 1.73\cdot 1.73 \cdot \mathbf{569}$ </td>
#             </tr>
#             <tr>
#                 <td> 2 </td>
#                 <td> 1.2 </td>
#                 <td> 2899 </td>
#                 <td> 609.36 </td>
#                 <td> $\checkmark$ $609.36 \leq 2\cdot 1.2 \cdot \mathbf{569}$ </td>
#             </tr>
#
#             <tr>
#                 <td> 2.5 </td>
#                 <td> 2 </td>
#                 <td> 2050 </td>
#                 <td> 680.83 </td>
#                 <td> $\checkmark$ $680.83 \leq 2.5\cdot 2 \cdot \mathbf{569}$ </td>
#             </tr>
#             <tr>
#                 <td> 5 </td>
#                 <td> 2 </td>
#                 <td> 2050 </td>
#                 <td> 680.83 </td>
#                 <td> $\checkmark$ $680.83 \leq 5\cdot 2 \cdot \mathbf{569}$ </td>
#             </tr>
#             <tr>
#                 <td> 10 </td>
#                 <td> 2 </td>
#                 <td> 2050 </td>
#                 <td> 680.83 </td>
#                 <td> $\checkmark$ $680.83 \leq 10 \cdot 2 \cdot \mathbf{569}$ </td>
#             </tr>
#         </table>
#     </div>
#     <div class="vis" style="margin-left: 270px;">
#         <img src="./imgs/mhastar_map2_w2w12.png" style="max-width: 70%" />
#     </div>
# </div>
#
# Note: The visualization is for $w_1 = 2$ and $w_2 = 1.2$.

# %% [markdown]
# ## Map 3

# %% [markdown]
# #### wA* Results

# %% [markdown]
# <div style="width: 100%; overflow: hidden;">
#     <div class="table" style="width: 400px; float: left;">
#         <table>
#             <tr>
#                 <th> $w$ </th>
#                 <th> # Expanded<br>Nodes </th>
#                 <th> Path Cost </th>
#                 <th> Within Bound<br>(Optimal Cost = 559) </th>
#             </tr>
#             <tr>
#                 <td> 2 </td>
#                 <td> 48274 </td>
#                 <td> 615.73 </td>
#                 <td> $\checkmark$ $615.73 \leq 2\cdot \mathbf{559}$ </td>
#             </tr>
#             <tr>
#                 <td> 3 </td>
#                 <td> 50609 </td>
#                 <td> 641.17 </td>
#                 <td> $\checkmark$ $641.17 \leq 3\cdot \mathbf{559}$ </td>
#             </tr>
#             <tr>
#                 <td> 5 </td>
#                 <td> 54039 </td>
#                 <td> 659.39 </td>
#                 <td> $\checkmark$ $659.39 \leq 5\cdot \mathbf{559}$ </td>
#             </tr>
#             <tr>
#                 <td> 10 </td>
#                 <td> 56463 </td>
#                 <td> 670.16 </td>
#                 <td> $\checkmark$ $670.16 \leq 10\cdot \mathbf{559}$ </td>
#             </tr>
#             <tr>
#                 <td> 20 </td>
#                 <td> 56908 </td>
#                 <td> 677.13 </td>
#                 <td> $\checkmark$ $677.13 \leq 20\cdot \mathbf{559}$ </td>
#             </tr>
#         </table>
#     </div>
#     <div class="vis" style="margin-left: 270px;">
#         <img src="./imgs/astar_map3_w20.png" style="max-width: 70%" />
#     </div>
# </div>
#
# Note: The visualization is for $w = 20$.

# %% [markdown]
# #### MHA* Results

# %% [markdown]
# <div style="width: 100%; overflow: hidden;">
#     <div class="table" style="width: 420px; float: left;">
#         <table>
#             <tr>
#                 <th> $w_1$ </th>
#                 <th> $w_2$ </th>
#                 <th> # Expanded<br>Nodes </th>
#                 <th> Path<br>Cost</th>
#                 <th> Within Bound (Optimal Cost = 559) </th>
#             </tr>
#             <tr>
#                 <td> 1.41 </td>
#                 <td> 1.41 </td>
#                 <td> 2050 </td>
#                 <td> 680.83 </td>
#                 <td> $\checkmark$ $680.83 \leq 1.41\cdot 1.41 \cdot \mathbf{559}$ </td>
#             </tr>
#             <tr>
#                 <td> 1.73 </td>
#                 <td> 1.73 </td>
#                 <td> 2050 </td>
#                 <td> 680.83 </td>
#                 <td> $\checkmark$ $680.83 \leq 1.73\cdot 1.73 \cdot \mathbf{559}$ </td>
#             </tr>
#             <tr>
#                 <td> 2 </td>
#                 <td> 1.2 </td>
#                 <td> 50842 </td>
#                 <td> 632.29 </td>
#                 <td> $\checkmark$ $632.29 \leq 2\cdot 1.2 \cdot \mathbf{559}$ </td>
#             </tr>
#             <tr>
#                 <td> 2.5 </td>
#                 <td> 2 </td>
#                 <td> 2050 </td>
#                 <td> 680.83 </td>
#                 <td> $\checkmark$ $680.83 \leq 2.5\cdot 2 \cdot \mathbf{559}$ </td>
#             </tr>
#             <tr>
#                 <td> 5 </td>
#                 <td> 2 </td>
#                 <td> 2050 </td>
#                 <td> 680.83 </td>
#                 <td> $\checkmark$ $680.83 \leq 5\cdot 2 \cdot \mathbf{559}$ </td>
#             </tr>
#             <tr>
#                 <td> 10 </td>
#                 <td> 2 </td>
#                 <td> 2050 </td>
#                 <td> 680.83 </td>
#                 <td> $\checkmark$ $680.83 \leq 10 \cdot 2 \cdot \mathbf{559}$ </td>
#             </tr>
#         </table>
#     </div>
#     <div class="vis" style="margin-left: 270px;">
#         <img src="./imgs/mhastar_map3_w20.png" style="max-width: 70%" />
#     </div>
# </div>
#
# Note: The visualization is for $w_1 = 10$ and $w_2 = 2$.

# %% [markdown]
# ### Discussion why wA\* takes a long time for map 3 in contrast to MHA\*

# %% [markdown]
# We can see that running wA\* on map 3 incurs a large runtime.  This is because the wA\* algorithm has a large wavefront and using only the Euclidean distance heuristic, it wants to try to cut across directly to the goal; however, as a result, it repeatedly becomes stuck in local minima, namely, in the bins.  There are significantly many more nodes expanded as a result, and the runtime grows drastically.  Moreover, as the weight for wA\* increases, the algorithm becomes more greedy towards reaching the goal and this causes the algorithm to get trapped in those bins.
#
# On the other hand, MHA\* handles this issue by utilizing the user-guidance heuristic.  This heuristic guides the expansion toward the bottom left corner, out of the way of the series of bins.  As a result, MHA\* avoids such regions and effectively provides a right-corner solution path with a significantly reduced runtime (much fewer expanded nodes).
#
# MHA\* avoids the bins at the price of a more costly path in its effort to avoid such local minima.  Thus, the paths produced by wA\* are of relatively lower cost.  However, it is important to note that with both MHA\* and weighted A\* once a weight is given, the algorithm is limited to be within that bound from the optimal cost path. The fact that the quality is not that good is okay because the user is willing to give up such optimality by specifying these weights for the benefits thereof.

# %% [markdown]
# ### General Discussion

# %% [markdown]
# For maps 1 and 3, we see how using MHA* with the extra, user-guided heuristic significantly reduces the number of expanded nodes since having that additional heuristic effectively helps avoid local minima, as can especially be seen with map 3 and the bins.  However, because the user-guided point is somewhat out of the way compared to the optimal solution, the path cost is not always better than the corresponding wA* path.  This can especially be seen with map 2.  Here, there aren't any local minima for the wA* search to fall into, so we can see that the wA* solutions have lower cost.  But again, as mentioned above, having a lower quality path is fine since the bound on the path cost is set by the user via the weights.
#
# We learned in class that theoretically, the cost of a wA* path is bounded by $w \cdot g^*(s_{\text{goal}})$.  Empirically, we showed this to hold in the results above, where the optimal cost was manually computed and the cost of the algorithm for each map for each weight was compared appropriately.  Similarly, we also learned that theoretically, the cost of an MHA* path is bounded by $w_1 \cdot w_2 \cdot g^*(s_\text{goal})$, and this was also shown empirically to hold true in the experimentation above.
#
# In terms of the runtime (which can only be discussed from an empirical perspective), we observed that the runtime was related to the specific type of environment.  For map 1, both wA* and MHA* decreased in the number of expanded nodes as the weights increased; for map 2, wA* also decreased in the number of expanded nodes for increased weight and then settled around a constant value for higher weight values while MHA* produced consistent cost paths reaching the guidance point and then the goal location; for map 3, wA* increased in number of expanded nodes for increased weight due to the greedy nature of trying to reach the goal but getting trapped while MHA* again produced consistent-cost, right-angle paths first hitting the guidance point and then reaching the goal location.
#
# Overall, MHA* provided an elegant way of incorporating the user-guided heuristic into the search problem, and we saw how it effectively avoided significant local minima compared to its wA* counterpart.
